# %% [markdown]
# <a href="https://colab.research.google.com/github/wxmiked/cannabis-deforestation/blob/feature-add-download-naip/notebooks/custom-raster-dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Cannabis Parcel Images for LabelMe
#
# Mike Dvorak [mike@weathertactics.io](mailto:mike@weathertactics.io)

# %% [markdown]
# ## Setup
#
# First, we install TorchGeo and a couple of other dependencies for downloading data from Microsoft's Planetary Computer.

# %%
# %pip install torchgeo planetary_computer pystac geopandas rasterio matplotlib
# Out:
# Requirement already satisfied: torchgeo in /Users/wxmiked/vscode-workspace/cannabis/cannabis-deforestation/.venv/lib/python3.11/site-packages (0.6.2)
# Requirement already satisfied: planetary_computer in /Users/wxmiked/vscode-workspace/cannabis/cannabis-deforestation/.venv/lib/python3.11/site-packages (1.0.0)
# Requirement already satisfied: pystac in /Users/wxmiked/vscode-workspace/cannabis/cannabis-deforestation/.venv/lib/python3.11/site-packages (1.12.2)
# Requirement already satisfied: geopandas in /Users/wxmiked/vscode-workspace/cannabis/cannabis-deforestation/.venv/lib/python3.11/site-packages (1.0.1)
# Requirement already satisfied: rasterio in /Users/wxmiked/vscode-workspace/cannabis/cannabis-deforestation/.venv/lib/python3.11/site-packages (1.4.3)
# Requirement already satisfied: matplotlib in /Users/wxmiked/vscode-workspace/cannabis/cannabis-deforestation/.venv/lib/python3.11/site-packages (3.10.0)
# Requirement already satisfied: einops>=0.3 in /Users/wxmiked/vscode-workspace/cannabis/cannabis-deforestation/.venv/lib/python3.11/site-packages (from torchgeo) (0.8.0)
# Requirement already satisfied: fiona>=1.8.21 in /Users/wxmiked/vscode-workspace/cannabis/cannabis-deforestation/.venv/lib/python3.11/site-packages (from torchgeo) (1.10.1)
# Requirement already satisfied: kornia>=0.7.3 in /Users/wxmiked/vscode-workspace/cannabis/cannabis-deforestation/.venv/lib/python3.11/site-packages (from torchgeo) (0.8.0)
# Requirement already satisfied: lightly!=1.4.26,>=1.4.5 in /Users/wxmiked/vscode-workspace/cannabis/cannabis-deforestation/.venv/lib/python3.11/site-packages (from torchgeo) (1.5.18)
# Requirement already satisfied: lightning!=2.3.*,>=2 in /Users/wxmiked/vscode-workspace/cannabis/cannabis-deforestation/.venv/lib/python3.11/site-packages (from lightning[pytorch-extra]!=2.3.*,>=2->torchgeo) (2.5.0.post0)
# Requirement already satisfied: numpy>=1.21.2 in /Users/wxmiked/vscode-workspace/cannabis/cannabis-deforestation/.venv/lib/python3.11/site-packages (from torchgeo) (2.2.2)
# Requirement already satisfied: pandas>=1.3.3 in /Users/wxmiked/vscode-workspace/cannabis/cannabis-deforestation/.venv/lib/python3.11/site-packages (from torchgeo) (2.2.3)
# Requirement already satisfied: pillow>=8.4 in /Users/wxmiked/vscode-workspace/cannabis/cannabis-deforestation/.venv/lib/python3.11/site-packages (from torchgeo) (11.1.0)
# Requirement already satisfied: pyproj>=3.3 in /Users/wxmiked/vscode-workspace/cannabis/cannabis-deforestation/.venv/lib/python3.11/site-packages (from torchgeo) (3.7.0)
# Requirement already satisfied: rtree>=1 in /Users/wxmiked/vscode-workspace/cannabis/cannabis-deforestation/.venv/lib/python3.11/site-packages (from torchgeo) (1.3.0)
# Requirement already satisfied: segmentation-models-pytorch>=0.2 in /Users/wxmiked/vscode-workspace/cannabis/cannabis-deforestation/.venv/lib/python3.11/site-packages (from torchgeo) (0.4.0)
# Requirement already satisfied: shapely>=1.8 in /Users/wxmiked/vscode-workspace/cannabis/cannabis-deforestation/.venv/lib/python3.11/site-packages (from torchgeo) (2.0.7)
# Requirement already satisfied: timm>=0.4.12 in /Users/wxmiked/vscode-workspace/cannabis/cannabis-deforestation/.venv/lib/python3.11/site-packages (from torchgeo) (1.0.14)
# Requirement already satisfied: torch>=1.13 in /Users/wxmiked/vscode-workspace/cannabis/cannabis-deforestation/.venv/lib/python3.11/site-packages (from torchgeo) (2.5.1)
# Requirement already satisfied: torchmetrics>=0.10 in /Users/wxmiked/vscode-workspace/cannabis/cannabis-deforestation/.venv/lib/python3.11/site-packages (from torchgeo) (1.6.1)
# Requirement already satisfied: torchvision>=0.14 in /Users/wxmiked/vscode-workspace/cannabis/cannabis-deforestation/.venv/lib/python3.11/site-packages (from torchgeo) (0.20.1)
# Requirement already satisfied: click>=7.1 in /Users/wxmiked/vscode-workspace/cannabis/cannabis-deforestation/.venv/lib/python3.11/site-packages (from planetary_computer) (8.1.8)
# Requirement already satisfied: pydantic>=1.7.3 in /Users/wxmiked/vscode-workspace/cannabis/cannabis-deforestation/.venv/lib/python3.11/site-packages (from planetary_computer) (2.10.6)
# Requirement already satisfied: pystac-client>=0.2.0 in /Users/wxmiked/vscode-workspace/cannabis/cannabis-deforestation/.venv/lib/python3.11/site-packages (from planetary_computer) (0.8.6)
# Requirement already satisfied: pytz>=2020.5 in /Users/wxmiked/vscode-workspace/cannabis/cannabis-deforestation/.venv/lib/python3.11/site-packages (from planetary_computer) (2025.1)
# Requirement already satisfied: requests>=2.25.1 in /Users/wxmiked/vscode-workspace/cannabis/cannabis-deforestation/.venv/lib/python3.11/site-packages (from planetary_computer) (2.32.3)
# Requirement already satisfied: packaging in /Users/wxmiked/vscode-workspace/cannabis/cannabis-deforestation/.venv/lib/python3.11/site-packages (from planetary_computer) (24.2)
# Requirement already satisfied: python-dotenv in /Users/wxmiked/vscode-workspace/cannabis/cannabis-deforestation/.venv/lib/python3.11/site-packages (from planetary_computer) (1.0.1)
# Requirement already satisfied: python-dateutil>=2.7.0 in /Users/wxmiked/vscode-workspace/cannabis/cannabis-deforestation/.venv/lib/python3.11/site-packages (from pystac) (2.9.0.post0)
# Requirement already satisfied: pyogrio>=0.7.2 in /Users/wxmiked/vscode-workspace/cannabis/cannabis-deforestation/.venv/lib/python3.11/site-packages (from geopandas) (0.10.0)
# Requirement already satisfied: affine in /Users/wxmiked/vscode-workspace/cannabis/cannabis-deforestation/.venv/lib/python3.11/site-packages (from rasterio) (2.4.0)
# Requirement already satisfied: attrs in /Users/wxmiked/vscode-workspace/cannabis/cannabis-deforestation/.venv/lib/python3.11/site-packages (from rasterio) (25.1.0)
# Requirement already satisfied: certifi in /Users/wxmiked/vscode-workspace/cannabis/cannabis-deforestation/.venv/lib/python3.11/site-packages (from rasterio) (2025.1.31)
# Requirement already satisfied: cligj>=0.5 in /Users/wxmiked/vscode-workspace/cannabis/cannabis-deforestation/.venv/lib/python3.11/site-packages (from rasterio) (0.7.2)
# Requirement already satisfied: click-plugins in /Users/wxmiked/vscode-workspace/cannabis/cannabis-deforestation/.venv/lib/python3.11/site-packages (from rasterio) (1.1.1)
# Requirement already satisfied: pyparsing in /Users/wxmiked/vscode-workspace/cannabis/cannabis-deforestation/.venv/lib/python3.11/site-packages (from rasterio) (3.2.1)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/wxmiked/vscode-workspace/cannabis/cannabis-deforestation/.venv/lib/python3.11/site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /Users/wxmiked/vscode-workspace/cannabis/cannabis-deforestation/.venv/lib/python3.11/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/wxmiked/vscode-workspace/cannabis/cannabis-deforestation/.venv/lib/python3.11/site-packages (from matplotlib) (4.55.8)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/wxmiked/vscode-workspace/cannabis/cannabis-deforestation/.venv/lib/python3.11/site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: kornia_rs>=0.1.0 in /Users/wxmiked/vscode-workspace/cannabis/cannabis-deforestation/.venv/lib/python3.11/site-packages (from kornia>=0.7.3->torchgeo) (0.1.8)
# Requirement already satisfied: hydra-core>=1.0.0 in /Users/wxmiked/vscode-workspace/cannabis/cannabis-deforestation/.venv/lib/python3.11/site-packages (from lightly!=1.4.26,>=1.4.5->torchgeo) (1.3.2)
# Requirement already satisfied: lightly_utils~=0.0.0 in /Users/wxmiked/vscode-workspace/cannabis/cannabis-deforestation/.venv/lib/python3.11/site-packages (from lightly!=1.4.26,>=1.4.5->torchgeo) (0.0.2)
# Requirement already satisfied: six>=1.10 in /Users/wxmiked/vscode-workspace/cannabis/cannabis-deforestation/.venv/lib/python3.11/site-packages (from lightly!=1.4.26,>=1.4.5->torchgeo) (1.17.0)
# Requirement already satisfied: tqdm>=4.44 in /Users/wxmiked/vscode-workspace/cannabis/cannabis-deforestation/.venv/lib/python3.11/site-packages (from lightly!=1.4.26,>=1.4.5->torchgeo) (4.67.1)
# Requirement already satisfied: pytorch_lightning>=1.0.4 in /Users/wxmiked/vscode-workspace/cannabis/cannabis-deforestation/.venv/lib/python3.11/site-packages (from lightly!=1.4.26,>=1.4.5->torchgeo) (2.5.0.post0)
# Requirement already satisfied: urllib3>=1.25.3 in /Users/wxmiked/vscode-workspace/cannabis/cannabis-deforestation/.venv/lib/python3.11/site-packages (from lightly!=1.4.26,>=1.4.5->torchgeo) (2.3.0)
# Requirement already satisfied: aenum>=3.1.11 in /Users/wxmiked/vscode-workspace/cannabis/cannabis-deforestation/.venv/lib/python3.11/site-packages (from lightly!=1.4.26,>=1.4.5->torchgeo) (3.1.15)
# Requirement already satisfied: PyYAML<8.0,>=5.4 in /Users/wxmiked/vscode-workspace/cannabis/cannabis-deforestation/.venv/lib/python3.11/site-packages (from lightning!=2.3.*,>=2->lightning[pytorch-extra]!=2.3.*,>=2->torchgeo) (6.0.2)
# Requirement already satisfied: fsspec<2026.0,>=2022.5.0 in /Users/wxmiked/vscode-workspace/cannabis/cannabis-deforestation/.venv/lib/python3.11/site-packages (from fsspec[http]<2026.0,>=2022.5.0->lightning!=2.3.*,>=2->lightning[pytorch-extra]!=2.3.*,>=2->torchgeo) (2024.12.0)
# Requirement already satisfied: lightning-utilities<2.0,>=0.10.0 in /Users/wxmiked/vscode-workspace/cannabis/cannabis-deforestation/.venv/lib/python3.11/site-packages (from lightning!=2.3.*,>=2->lightning[pytorch-extra]!=2.3.*,>=2->torchgeo) (0.12.0)
# Requirement already satisfied: typing-extensions<6.0,>=4.4.0 in /Users/wxmiked/vscode-workspace/cannabis/cannabis-deforestation/.venv/lib/python3.11/site-packages (from lightning!=2.3.*,>=2->lightning[pytorch-extra]!=2.3.*,>=2->torchgeo) (4.12.2)
# Requirement already satisfied: jsonargparse<5.0,>=4.27.7 in /Users/wxmiked/vscode-workspace/cannabis/cannabis-deforestation/.venv/lib/python3.11/site-packages (from jsonargparse[signatures]<5.0,>=4.27.7; extra == "pytorch-extra"->lightning[pytorch-extra]!=2.3.*,>=2->torchgeo) (4.36.0)
# Requirement already satisfied: omegaconf<3.0,>=2.2.3 in /Users/wxmiked/vscode-workspace/cannabis/cannabis-deforestation/.venv/lib/python3.11/site-packages (from lightning[pytorch-extra]!=2.3.*,>=2->torchgeo) (2.3.0)
# Requirement already satisfied: rich<14.0,>=12.3.0 in /Users/wxmiked/vscode-workspace/cannabis/cannabis-deforestation/.venv/lib/python3.11/site-packages (from lightning[pytorch-extra]!=2.3.*,>=2->torchgeo) (13.9.4)
# Requirement already satisfied: tensorboardX<3.0,>=2.2 in /Users/wxmiked/vscode-workspace/cannabis/cannabis-deforestation/.venv/lib/python3.11/site-packages (from lightning[pytorch-extra]!=2.3.*,>=2->torchgeo) (2.6.2.2)
# Requirement already satisfied: bitsandbytes<1.0,>=0.42.0 in /Users/wxmiked/vscode-workspace/cannabis/cannabis-deforestation/.venv/lib/python3.11/site-packages (from lightning[pytorch-extra]!=2.3.*,>=2->torchgeo) (0.42.0)
# Requirement already satisfied: tzdata>=2022.7 in /Users/wxmiked/vscode-workspace/cannabis/cannabis-deforestation/.venv/lib/python3.11/site-packages (from pandas>=1.3.3->torchgeo) (2025.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/wxmiked/vscode-workspace/cannabis/cannabis-deforestation/.venv/lib/python3.11/site-packages (from pydantic>=1.7.3->planetary_computer) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /Users/wxmiked/vscode-workspace/cannabis/cannabis-deforestation/.venv/lib/python3.11/site-packages (from pydantic>=1.7.3->planetary_computer) (2.27.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/wxmiked/vscode-workspace/cannabis/cannabis-deforestation/.venv/lib/python3.11/site-packages (from requests>=2.25.1->planetary_computer) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /Users/wxmiked/vscode-workspace/cannabis/cannabis-deforestation/.venv/lib/python3.11/site-packages (from requests>=2.25.1->planetary_computer) (3.10)
# Requirement already satisfied: efficientnet-pytorch>=0.6.1 in /Users/wxmiked/vscode-workspace/cannabis/cannabis-deforestation/.venv/lib/python3.11/site-packages (from segmentation-models-pytorch>=0.2->torchgeo) (0.7.1)
# Requirement already satisfied: huggingface-hub>=0.24 in /Users/wxmiked/vscode-workspace/cannabis/cannabis-deforestation/.venv/lib/python3.11/site-packages (from segmentation-models-pytorch>=0.2->torchgeo) (0.28.1)
# Requirement already satisfied: pretrainedmodels>=0.7.1 in /Users/wxmiked/vscode-workspace/cannabis/cannabis-deforestation/.venv/lib/python3.11/site-packages (from segmentation-models-pytorch>=0.2->torchgeo) (0.7.4)
# Requirement already satisfied: safetensors in /Users/wxmiked/vscode-workspace/cannabis/cannabis-deforestation/.venv/lib/python3.11/site-packages (from timm>=0.4.12->torchgeo) (0.5.2)
# Requirement already satisfied: filelock in /Users/wxmiked/vscode-workspace/cannabis/cannabis-deforestation/.venv/lib/python3.11/site-packages (from torch>=1.13->torchgeo) (3.17.0)
# Requirement already satisfied: networkx in /Users/wxmiked/vscode-workspace/cannabis/cannabis-deforestation/.venv/lib/python3.11/site-packages (from torch>=1.13->torchgeo) (3.4.2)
# Requirement already satisfied: jinja2 in /Users/wxmiked/vscode-workspace/cannabis/cannabis-deforestation/.venv/lib/python3.11/site-packages (from torch>=1.13->torchgeo) (3.1.5)
# Requirement already satisfied: sympy==1.13.1 in /Users/wxmiked/vscode-workspace/cannabis/cannabis-deforestation/.venv/lib/python3.11/site-packages (from torch>=1.13->torchgeo) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/wxmiked/vscode-workspace/cannabis/cannabis-deforestation/.venv/lib/python3.11/site-packages (from sympy==1.13.1->torch>=1.13->torchgeo) (1.3.0)
# Requirement already satisfied: scipy in /Users/wxmiked/vscode-workspace/cannabis/cannabis-deforestation/.venv/lib/python3.11/site-packages (from bitsandbytes<1.0,>=0.42.0->lightning[pytorch-extra]!=2.3.*,>=2->torchgeo) (1.15.1)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /Users/wxmiked/vscode-workspace/cannabis/cannabis-deforestation/.venv/lib/python3.11/site-packages (from fsspec[http]<2026.0,>=2022.5.0->lightning!=2.3.*,>=2->lightning[pytorch-extra]!=2.3.*,>=2->torchgeo) (3.11.11)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /Users/wxmiked/vscode-workspace/cannabis/cannabis-deforestation/.venv/lib/python3.11/site-packages (from hydra-core>=1.0.0->lightly!=1.4.26,>=1.4.5->torchgeo) (4.9.3)
# Requirement already satisfied: docstring-parser>=0.15 in /Users/wxmiked/vscode-workspace/cannabis/cannabis-deforestation/.venv/lib/python3.11/site-packages (from jsonargparse[signatures]<5.0,>=4.27.7; extra == "pytorch-extra"->lightning[pytorch-extra]!=2.3.*,>=2->torchgeo) (0.16)
# Requirement already satisfied: typeshed-client>=2.1.0 in /Users/wxmiked/vscode-workspace/cannabis/cannabis-deforestation/.venv/lib/python3.11/site-packages (from jsonargparse[signatures]<5.0,>=4.27.7; extra == "pytorch-extra"->lightning[pytorch-extra]!=2.3.*,>=2->torchgeo) (2.7.0)
# Requirement already satisfied: setuptools in /Users/wxmiked/vscode-workspace/cannabis/cannabis-deforestation/.venv/lib/python3.11/site-packages (from lightning-utilities<2.0,>=0.10.0->lightning!=2.3.*,>=2->lightning[pytorch-extra]!=2.3.*,>=2->torchgeo) (65.5.0)
# Requirement already satisfied: munch in /Users/wxmiked/vscode-workspace/cannabis/cannabis-deforestation/.venv/lib/python3.11/site-packages (from pretrainedmodels>=0.7.1->segmentation-models-pytorch>=0.2->torchgeo) (4.0.0)
# Requirement already satisfied: jsonschema~=4.18 in /Users/wxmiked/vscode-workspace/cannabis/cannabis-deforestation/.venv/lib/python3.11/site-packages (from pystac[validation]>=1.10.0->pystac-client>=0.2.0->planetary_computer) (4.23.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/wxmiked/vscode-workspace/cannabis/cannabis-deforestation/.venv/lib/python3.11/site-packages (from rich<14.0,>=12.3.0->lightning[pytorch-extra]!=2.3.*,>=2->torchgeo) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/wxmiked/vscode-workspace/cannabis/cannabis-deforestation/.venv/lib/python3.11/site-packages (from rich<14.0,>=12.3.0->lightning[pytorch-extra]!=2.3.*,>=2->torchgeo) (2.19.1)
# Requirement already satisfied: protobuf>=3.20 in /Users/wxmiked/vscode-workspace/cannabis/cannabis-deforestation/.venv/lib/python3.11/site-packages (from tensorboardX<3.0,>=2.2->lightning[pytorch-extra]!=2.3.*,>=2->torchgeo) (5.29.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/wxmiked/vscode-workspace/cannabis/cannabis-deforestation/.venv/lib/python3.11/site-packages (from jinja2->torch>=1.13->torchgeo) (3.0.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /Users/wxmiked/vscode-workspace/cannabis/cannabis-deforestation/.venv/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning!=2.3.*,>=2->lightning[pytorch-extra]!=2.3.*,>=2->torchgeo) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/wxmiked/vscode-workspace/cannabis/cannabis-deforestation/.venv/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning!=2.3.*,>=2->lightning[pytorch-extra]!=2.3.*,>=2->torchgeo) (1.3.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/wxmiked/vscode-workspace/cannabis/cannabis-deforestation/.venv/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning!=2.3.*,>=2->lightning[pytorch-extra]!=2.3.*,>=2->torchgeo) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/wxmiked/vscode-workspace/cannabis/cannabis-deforestation/.venv/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning!=2.3.*,>=2->lightning[pytorch-extra]!=2.3.*,>=2->torchgeo) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /Users/wxmiked/vscode-workspace/cannabis/cannabis-deforestation/.venv/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning!=2.3.*,>=2->lightning[pytorch-extra]!=2.3.*,>=2->torchgeo) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /Users/wxmiked/vscode-workspace/cannabis/cannabis-deforestation/.venv/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning!=2.3.*,>=2->lightning[pytorch-extra]!=2.3.*,>=2->torchgeo) (1.18.3)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Users/wxmiked/vscode-workspace/cannabis/cannabis-deforestation/.venv/lib/python3.11/site-packages (from jsonschema~=4.18->pystac[validation]>=1.10.0->pystac-client>=0.2.0->planetary_computer) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in /Users/wxmiked/vscode-workspace/cannabis/cannabis-deforestation/.venv/lib/python3.11/site-packages (from jsonschema~=4.18->pystac[validation]>=1.10.0->pystac-client>=0.2.0->planetary_computer) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /Users/wxmiked/vscode-workspace/cannabis/cannabis-deforestation/.venv/lib/python3.11/site-packages (from jsonschema~=4.18->pystac[validation]>=1.10.0->pystac-client>=0.2.0->planetary_computer) (0.24.0)
# Requirement already satisfied: mdurl~=0.1 in /Users/wxmiked/vscode-workspace/cannabis/cannabis-deforestation/.venv/lib/python3.11/site-packages (from markdown-it-py>=2.2.0->rich<14.0,>=12.3.0->lightning[pytorch-extra]!=2.3.*,>=2->torchgeo) (0.1.2)
# Requirement already satisfied: importlib-resources>=1.4.0 in /Users/wxmiked/vscode-workspace/cannabis/cannabis-deforestation/.venv/lib/python3.11/site-packages (from typeshed-client>=2.1.0->jsonargparse[signatures]<5.0,>=4.27.7; extra == "pytorch-extra"->lightning[pytorch-extra]!=2.3.*,>=2->torchgeo) (6.5.2)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Imports
#
# Next, we import TorchGeo and any other libraries we need.

# %%
import os
import tempfile
from urllib.parse import urlparse

import matplotlib.pyplot as plt
import planetary_computer
import pystac
import torch
from torch.utils.data import DataLoader

from torchgeo.datasets.utils import download_url
from torchgeo.samplers import RandomGeoSampler, Units
from torchgeo.transforms import AppendNDBI, AppendNDVI, AppendNDWI

# %matplotlib inline
plt.rcParams['figure.figsize'] = (4, 4)

# %% [markdown]
# ## Downloading
#
# Let's download some data to play around with. In this example, we'll create a dataset for loading Sentinel-2 images. Yes, TorchGeo already has a built-in class for this, but we'll use it as an example of the steps you would need to take to add a dataset that isn't yet available in TorchGeo. We'll show how to download a few bands of Sentinel-2 imagery from the Planetary Computer. This may take a few minutes.

# %%
import pystac_client
import planetary_computer

catalog = pystac_client.Client.open(
    "https://planetarycomputer.microsoft.com/api/stac/v1",
    modifier=planetary_computer.sign_inplace,
)

# %%
time_range = "2016-01-01/2016-12-31"
bbox = [-120.56802294590112,38.307368125981206,-120.47440785318257,38.36284893862011]


search = catalog.search(collections=["naip"], bbox=bbox, datetime=time_range)
items = search.item_collection()
items
# Out:
# <style>
# .pystac-summary {
#     cursor: pointer;
#     display: list-item;
#     list-style: revert;
#     margin-bottom: 0 !important;
#
#     .pystac-l {
#         padding-left: 0.5em;
#         color: rgb(64, 128, 128);
#         font-style: italic;
#     }
# }
# .pystac-row {
#     overflow-wrap: break-word;
#     padding-left: .825em;
#
#     .pystac-k {
#         display: inline-block;
#         margin: 0px 0.5em 0px 0px;
#     }
#     .pystac-v {
#         color: rgb(186, 33, 33);
#     }
# }
# .pystac-k {
#     color: rgb(0, 128, 0);
#     font-weight: 700;
# }
# </style>
# <div class="jp-RenderedJSON jp-mod-trusted jp-OutputArea-output">
#     <div class="container" style="line-height: normal;">
#         <ul style="padding: 0px; margin: 0px; list-style: none; display: block;">
#
#
#
#         <li class="pystac-row">
#             <span class="pystac-k">type</span>
#             <span class="pystac-v">"FeatureCollection"</span>
#         </li>
#
#
#
#
#                     <li><details>
#         <summary class="pystac-summary"><span class="pystac-k">features</span><span class="pystac-l">[] 6 items</span></summary>
#
#             <ul style="margin: 0px; padding: 0px 0px 0px 1.75em; list-style: none; display: block;">
#
#
#
#         <li><details>
#             <summary class="pystac-summary"><span class="pystac-k">0</span></summary>
#             <ul style="margin: 0px; padding: 0px 0px 0px 1.75em; list-style: none; display: block;">
#
#
#
#         <li class="pystac-row">
#             <span class="pystac-k">type</span>
#             <span class="pystac-v">"Feature"</span>
#         </li>
#
#
#
#
#
#         <li class="pystac-row">
#             <span class="pystac-k">stac_version</span>
#             <span class="pystac-v">"1.1.0"</span>
#         </li>
#
#
#
#
#                 <li><details>
#         <summary class="pystac-summary"><span class="pystac-k">stac_extensions</span><span class="pystac-l">[] 2 items</span></summary>
#
#             <ul style="margin: 0px; padding: 0px 0px 0px 1.75em; list-style: none; display: block;">
#
#
#
#         <li class="pystac-row">
#             <span class="pystac-k">0</span>
#             <span class="pystac-v">"https://stac-extensions.github.io/eo/v1.1.0/schema.json"</span>
#         </li>
#
#
#
#     </ul>
#
#             <ul style="margin: 0px; padding: 0px 0px 0px 1.75em; list-style: none; display: block;">
#
#
#
#         <li class="pystac-row">
#             <span class="pystac-k">1</span>
#             <span class="pystac-v">"https://stac-extensions.github.io/projection/v2.0.0/schema.json"</span>
#         </li>
#
#
#
#     </ul>
#
#     </details></li>
#
#
#
#
#         <li class="pystac-row">
#             <span class="pystac-k">id</span>
#             <span class="pystac-v">"ca_m_3812045_sw_10_.6_20160620_20161004"</span>
#         </li>
#
#
#
#
#
#         <li><details>
#             <summary class="pystac-summary"><span class="pystac-k">geometry</span></summary>
#             <ul style="margin: 0px; padding: 0px 0px 0px 1.75em; list-style: none; display: block;">
#
#
#
#         <li class="pystac-row">
#             <span class="pystac-k">type</span>
#             <span class="pystac-v">"Polygon"</span>
#         </li>
#
#
#
#
#                 <li><details>
#         <summary class="pystac-summary"><span class="pystac-k">coordinates</span><span class="pystac-l">[] 1 items</span></summary>
#
#             <ul style="margin: 0px; padding: 0px 0px 0px 1.75em; list-style: none; display: block;">
#
#
#                 <li><details>
#         <summary class="pystac-summary"><span class="pystac-k">0</span><span class="pystac-l">[] 5 items</span></summary>
#
#             <ul style="margin: 0px; padding: 0px 0px 0px 1.75em; list-style: none; display: block;">
#
#
#                 <li><details>
#         <summary class="pystac-summary"><span class="pystac-k">0</span><span class="pystac-l">[] 2 items</span></summary>
#
#             <ul style="margin: 0px; padding: 0px 0px 0px 1.75em; list-style: none; display: block;">
#
#
#
#         <li class="pystac-row">
#             <span class="pystac-k">0</span>
#             <span class="pystac-v">-120.435843</span>
#         </li>
#
#
#
#     </ul>
#
#             <ul style="margin: 0px; padding: 0px 0px 0px 1.75em; list-style: none; display: block;">
#
#
#
#         <li class="pystac-row">
#             <span class="pystac-k">1</span>
#             <span class="pystac-v">38.247215</span>
#         </li>
#
#
#
#     </ul>
#
#     </details></li>
#
#
#     </ul>
#
#             <ul style="margin: 0px; padding: 0px 0px 0px 1.75em; list-style: none; display: block;">
#
#
#                 <li><details>
#         <summary class="pystac-summary"><span class="pystac-k">1</span><span class="pystac-l">[] 2 items</span></summary>
#
#             <ul style="margin: 0px; padding: 0px 0px 0px 1.75em; list-style: none; display: block;">
#
#
#
#         <li class="pystac-row">
#             <span class="pystac-k">0</span>
#             <span class="pystac-v">-120.433499</span>
#         </li>
#
#
#
#     </ul>
#
#             <ul style="margin: 0px; padding: 0px 0px 0px 1.75em; list-style: none; display: block;">
#
#
#
#         <li class="pystac-row">
#             <span class="pystac-k">1</span>
#             <span class="pystac-v">38.313768</span>
#         </li>
#
#
#
#     </ul>
#
#     </details></li>
#
#
#     </ul>
#
#             <ul style="margin: 0px; padding: 0px 0px 0px 1.75em; list-style: none; display: block;">
#
#
#                 <li><details>
#         <summary class="pystac-summary"><span class="pystac-k">2</span><span class="pystac-l">[] 2 items</span></summary>
#
#             <ul style="margin: 0px; padding: 0px 0px 0px 1.75em; list-style: none; display: block;">
#
#
#
#         <li class="pystac-row">
#             <span class="pystac-k">0</span>
#             <span class="pystac-v">-120.501654</span>
#         </li>
#
#
#
#     </ul>
#
#             <ul style="margin: 0px; padding: 0px 0px 0px 1.75em; list-style: none; display: block;">
#
#
#
#         <li class="pystac-row">
#             <span class="pystac-k">1</span>
#             <span class="pystac-v">38.31524</span>
#         </li>
#
#
#
#     </ul>
#
#     </details></li>
#
#
#     </ul>
#
#             <ul style="margin: 0px; padding: 0px 0px 0px 1.75em; list-style: none; display: block;">
#
#
#                 <li><details>
#         <summary class="pystac-summary"><span class="pystac-k">3</span><span class="pystac-l">[] 2 items</span></summary>
#
#             <ul style="margin: 0px; padding: 0px 0px 0px 1.75em; list-style: none; display: block;">
#
#
#
#         <li class="pystac-row">
#             <span class="pystac-k">0</span>
#             <span class="pystac-v">-120.503935</span>
#         </li>
#
#
#
#     </ul>
#
#             <ul style="margin: 0px; padding: 0px 0px 0px 1.75em; list-style: none; display: block;">
#
#
#
#         <li class="pystac-row">
#             <span class="pystac-k">1</span>
#             <span class="pystac-v">38.248683</span>
#         </li>

# %%
import os
from urllib.parse import urlparse
import tempfile

root = os.path.join(tempfile.gettempdir(), 'naip')
os.makedirs(root, exist_ok=True)  # Ensure the directory exists

for item in items:
    signed_item = planetary_computer.sign(item)
    url = signed_item.assets["image"].href
    filename = urlparse(url).path.split('/')[-1]
    
    # Check if file already exists
    filepath = os.path.join(root, filename)
    if not os.path.exists(filepath):
        print(f"Downloading {filename}...")
        download_url(url, root, filename)
    else:
        print(f"Skipping {filename} - already exists")
# Out:
# Skipping m_3812045_sw_10_h_20160620.tif - already exists
# Skipping m_3812045_nw_10_h_20160620.tif - already exists
# Skipping m_3812044_sw_10_h_20160620.tif - already exists
# Skipping m_3812044_se_10_h_20160620.tif - already exists
# Skipping m_3812044_nw_10_h_20160620.tif - already exists
# Skipping m_3812044_ne_10_h_20160620.tif - already exists

# %% [markdown]
# This downloads the following files:

# %%
print(root)
sorted(os.listdir(root))
# Out:
# /var/folders/56/gwh1m3s973l4jc97_wdr2qqw0000gn/T/naip
# ['m_3812044_ne_10_h_20160620.tif',
#  'm_3812044_nw_10_h_20160620.json',
#  'm_3812044_nw_10_h_20160620.tif',
#  'm_3812044_se_10_h_20160620.tif',
#  'm_3812044_sw_10_h_20160620.tif',
#  'm_3812045_nw_10_h_20160620.tif',
#  'm_3812045_sw_10_h_20160620.tif']

# %% [markdown]
# ## Crop the images to cannabis parcels
#
# We want to create a training images of cannabis growing operations (hoop houses and rows of plants) for an instance segmentation model that will classify new NAIP images.

# %%
import geopandas as gpd
import rasterio
from rasterio.mask import mask
from shapely.geometry import box
import os
from pathlib import Path
import re

# only pick up the NAIP files whose names contain a date
filename_glob  = 'm_*.tif'
filename_regex = r'^m_[0-9]{7}_[nsew]{2}_10_h_(?P<date>\d{8})'
date_pattern   = re.compile(filename_regex)

# Define paths
parcels_path = "../cannabis-parcels/cannabis-registry-2018-commercial-permits-parcels.gpkg"
output_dir = "../cannabis-parcels/cannabis-parcels-masked/"
naip_dir = "../data-to-import/microsoft/naip/calaveras-county-west-point-training-set"  # Assuming this is where your NAIP images are stored

# Create output directory if it doesn't exist
os.makedirs(output_dir, exist_ok=True)

# Get NAIP CRS from first image
naip_crs = None
for naip_file in Path(naip_dir).glob('*.tif'):
    with rasterio.open(naip_file) as src:
        naip_crs = src.crs
        print(f"NAIP CRS: {naip_crs}")
        break

if naip_crs is None:
    raise ValueError("No NAIP images found to determine CRS")

# Read the parcels GeoPackage and reproject to NAIP CRS
parcels = gpd.read_file(parcels_path)
print(f"Original parcels CRS: {parcels.crs}")
parcels = parcels.to_crs(naip_crs)
print(f"Reprojected parcels to: {parcels.crs}")

# Filter for cannabis parcels
cannabis_parcels = parcels[parcels['cannabis_permit'] == 1]

# Function to process each parcel
def process_parcel(row):
    apn = row['APN']
    geometry = row['geometry']
    bounds = geometry.bounds
    minx, miny, maxx, maxy = bounds
    polygon_bounds = box(minx, miny, maxx, maxy)

    # Find matching NAIP image
    for naip_file in Path(naip_dir).glob(filename_glob):
        file_name = naip_file.name
        m = date_pattern.match(file_name)
        if not m:
            # skip any file that doesn't match your naming scheme
            continue

        date = m.group('date')   # e.g. '20160721'
        with rasterio.open(naip_file) as src:
            try:
                out_image, out_transform = mask(src, [polygon_bounds], crop=True, filled=True)
                out_meta = src.meta.copy()
                out_meta.update({
                    "driver": "GTiff",
                    "height": out_image.shape[1],
                    "width":  out_image.shape[2],
                    "transform": out_transform
                })

                # include both APN and date in the filename
                output_path = os.path.join(output_dir, f"{apn}_{date}.tif")
                with rasterio.open(output_path, "w", **out_meta) as dest:
                    dest.write(out_image)

                print(f"Processed parcel {apn} ({date})")
                break
            except ValueError:
                continue

# Process each cannabis parcel
for _, row in cannabis_parcels.iterrows():
    process_parcel(row)

print("Processing complete!")
# Out:
# NAIP CRS: EPSG:26910
# Original parcels CRS: EPSG:4326
# Reprojected parcels to: PROJCS["NAD83 / UTM zone 10N",GEOGCS["NAD83",DATUM["North_American_Datum_1983",SPHEROID["GRS 1980",6378137,298.257222101,AUTHORITY["EPSG","7019"]],AUTHORITY["EPSG","6269"]],PRIMEM["Greenwich",0,AUTHORITY["EPSG","8901"]],UNIT["degree",0.0174532925199433,AUTHORITY["EPSG","9122"]],AUTHORITY["EPSG","4269"]],PROJECTION["Transverse_Mercator"],PARAMETER["latitude_of_origin",0],PARAMETER["central_meridian",-123],PARAMETER["scale_factor",0.9996],PARAMETER["false_easting",500000],PARAMETER["false_northing",0],UNIT["metre",1,AUTHORITY["EPSG","9001"]],AXIS["Easting",EAST],AXIS["Northing",NORTH],AUTHORITY["EPSG","26910"]]
# Processed parcel 21022005 (20160620)
# Processed parcel 21019030 (20160620)
# Processed parcel 21010030 (20160620)
# Processed parcel 16025150 (20160620)
# Processed parcel 21010009 (20160620)
# Processed parcel 21010046 (20160620)
# Processed parcel 21001049 (20160620)
# Processed parcel 21013029 (20160620)
# Processed parcel 21015072 (20160620)
# Processed parcel 21022001 (20160620)
# Processed parcel 16025130 (20160620)
# Processed parcel 21019026 (20160620)
# Processed parcel 16025047 (20160620)
# Processed parcel 21004116 (20160620)
# Processed parcel 21004115 (20160620)
# Processed parcel 16025050 (20160620)
# Processed parcel 21009018 (20160620)
# Processed parcel 21009004 (20160620)
# Processed parcel 21004104 (20160620)
# Processed parcel 21004092 (20160620)
# Processed parcel 21004016 (20160620)
# Processed parcel 21004078 (20160620)
# Processed parcel 21004018 (20160620)
# Processed parcel 21004083 (20160620)
# Processed parcel 21016018 (20160620)
# Processed parcel 21004085 (20160620)
# Processed parcel 21004088 (20160620)
# Processed parcel 20012034 (20160620)
# Processed parcel 20012017 (20160620)
# Processed parcel 20027093 (20160620)
# Processed parcel 20027090 (20160620)
# Processed parcel 20027177 (20160620)
# Processed parcel 20025018 (20160620)
# Processed parcel 20032011 (20160620)
# Processed parcel 20016001 (20160620)
# Processed parcel 20012020 (20160620)
